# %%
# !pip install transformers peft trl accelerate bitsandbytes datasets -q

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("RAM available:", round(torch.cuda.get_device_properties(0).total_memory/1e9, 2), "GB") if torch.cuda.is_available() else print("Running on CPU")
# Out:
# PyTorch version: 2.11.0+cpu
# CUDA available: False
# Running on CPU
